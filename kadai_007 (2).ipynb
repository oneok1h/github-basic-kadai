# %%
# ライブラリーをインポートする
import matplotlib.pyplot as plt
import pandas as pd
import japanize_matplotlib

# 棒グラフ
x = np.array([1, 2, 3, 4, 5])
y = np.array([500, 480, 450, 350, 460])
label = ["ハンバーグ", "生姜焼き" , "野菜炒め", "のり", "唐揚げ"]
plt.title("お弁当の値段")
plt.bar(x, y, tick_label=label)

plt.show()

# pandasを使ったデータ分析
data = {
     'お弁当の種類': ["ハンバーグ", "生姜焼き" , "野菜炒め", "のり", "唐揚げ"],
     '価格': [500, 480, 450, 350, 460]
}
df = pd.DataFrame(data)

grouped_data = df.groupby('お弁当の種類')['価格'].sum()
print(grouped_data)
# Out:
# お弁当の種類
# のり       350
# ハンバーグ    500
# 唐揚げ      460
# 生姜焼き     480
# 野菜炒め     450
# Name: 価格, dtype: int64
